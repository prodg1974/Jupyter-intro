# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
mycol = df.columns.get_values().tolist()

# %%
mycol
# Out:
# ['col1', 'col2']

# %%
df_games = pd.read_csv('../Data/GL2017.TXT', names=["Date","DoubleHeader","DayOfWeek","VisitingTeam","VisitingTeamLeague","VisitingTeamGameNumber","HomeTeam","HomeTeamLeague","HomeTeamGameNumber","VisitorRunsScored","HomeRunsScore","LengthInOuts","DayNight","CompletionInfo","ForfeitInfo","ProtestInfo","ParkID","Attendence","Duration","VisitorLineScore","HomeLineScore","VisitorAB","VisitorH","VisitorD","VisitorT","VisitorHR","VisitorRBI","VisitorSH","VisitorSF","VisitorHBP","VisitorBB","VisitorIBB","VisitorK","VisitorSB","VisitorCS","VisitorGDP","VisitorCI","VisitorLOB","VisitorPitchers","VisitorER","VisitorTER","VisitorWP","VisitorBalks","VisitorPO","VisitorA","VisitorE","VisitorPassed","VisitorDB","VisitorTP","HomeAB","HomeH","HomeD","HomeT","HomeHR","HomeRBI","HomeSH","HomeSF","HomeHBP","HomeBB","HomeIBB","HomeK","HomeSB","HomeCS","HomeGDP","HomeCI","HomeLOB","HomePitchers","HomeER","HomeTER","HomeWP","HomeBalks","HomePO","HomeA","HomeE","HomePassed","HomeDB","HomeTP","UmpireHID","UmpireHName","Umpire1BID","Umpire1BName","Umpire2BID","Umpire2BName","Umpire3BID","Umpire3BName","UmpireLFID","UmpireLFName","UmpireRFID","UmpireRFName","VisitorManagerID","VisitorManagerName","HomeManagerID","HomeManagerName","WinningPitcherID","WinningPitcherName","LosingPitcherID","LosingPitcherNAme","SavingPitcherID","SavingPitcherName","GameWinningRBIID","GameWinningRBIName","VisitorStartingPitcherID","VisitorStartingPitcherName","HomeStartingPitcherID","HomeStartingPitcherName","VisitorBatting1PlayerID","VisitorBatting1Name","VisitorBatting1Position","VisitorBatting2PlayerID","VisitorBatting2Name","VisitorBatting2Position","VisitorBatting3PlayerID","VisitorBatting3Name","VisitorBatting3Position","VisitorBatting4PlayerID","VisitorBatting4Name","VisitorBatting4Position","VisitorBatting5PlayerID","VisitorBatting5Name","VisitorBatting5Position","VisitorBatting6PlayerID","VisitorBatting6Name","VisitorBatting6Position","VisitorBatting7PlayerID","VisitorBatting7Name","VisitorBatting7Position","VisitorBatting8PlayerID","VisitorBatting8Name","VisitorBatting8Position","VisitorBatting9PlayerID","VisitorBatting9Name","VisitorBatting9Position","HomeBatting1PlayerID","HomeBatting1Name","HomeBatting1Position","HomeBatting2PlayerID","HomeBatting2Name","HomeBatting2Position","HomeBatting3PlayerID","HomeBatting3Name","HomeBatting3Position","HomeBatting4PlayerID","HomeBatting4Name","HomeBatting4Position","HomeBatting5PlayerID","HomeBatting5Name","HomeBatting5Position","HomeBatting6PlayerID","HomeBatting6Name","HomeBatting6Position","HomeBatting7PlayerID","HomeBatting7Name","HomeBatting7Position","HomeBatting8PlayerID","HomeBatting8Name","HomeBatting8Position","HomeBatting9PlayerID","HomeBatting9Name","HomeBatting9Position","AdditionalInfo","AcquisitionInfo"])

# %%
df_games[df_games.VisitingTeam == 'BOS'].head ()
# Out:
#          Date  DoubleHeader DayOfWeek VisitingTeam VisitingTeamLeague  \
# 59   20170407             0       Fri          BOS                 AL
# 74   20170408             0       Sat          BOS                 AL
# 89   20170409             0       Sun          BOS                 AL
# 99   20170410             0       Mon          BOS                 AL
# 209  20170418             0       Tue          BOS                 AL
#
#      VisitingTeamGameNumber HomeTeam HomeTeamLeague  HomeTeamGameNumber  \
# 59                        3      DET             AL                   3
# 74                        4      DET             AL                   4
# 89                        5      DET             AL                   5
# 99                        6      DET             AL                   6
# 209                      14      TOR             AL                  13
#
#      VisitorRunsScored       ...        HomeBatting7Name  \
# 59                   5       ...            James McCann
# 74                   1       ...            James McCann
# 89                   7       ...              Alex Avila
# 99                   1       ...           Jose Iglesias
# 209                  8       ...            Steve Pearce
#
#      HomeBatting7Position HomeBatting8PlayerID  HomeBatting8Name  \
# 59                      2             jonej006      JaCoby Jones
# 74                      2             jonej006      JaCoby Jones
# 89                      2             romia001     Andrew Romine
# 99                      6             jonej006      JaCoby Jones
# 209                     7             barnd001     Darwin Barney
#
#      HomeBatting8Position  HomeBatting9PlayerID HomeBatting9Name  \
# 59                      8              iglej001    Jose Iglesias
# 74                      8              iglej001    Jose Iglesias
# 89                      8              iglej001    Jose Iglesias
# 99                      8              romia001    Andrew Romine
# 209                     5              travd001     Devon Travis
#
#      HomeBatting9Position  AdditionalInfo AcquisitionInfo
# 59                      6             NaN               Y
# 74                      6             NaN               Y
# 89                      6             NaN               Y
# 99                      7             NaN               Y
# 209                     4             NaN               Y
#
# [5 rows x 161 columns]

# %%
df_games[(df_games['VisitingTeam'] == 'BOS') | (df_games['HomeTeam'] == 'BOS')].head()
# Out:
#         Date  DoubleHeader DayOfWeek VisitingTeam VisitingTeamLeague  \
# 9   20170403             0       Mon          PIT                 NL
# 30  20170405             0       Wed          PIT                 NL
# 59  20170407             0       Fri          BOS                 AL
# 74  20170408             0       Sat          BOS                 AL
# 89  20170409             0       Sun          BOS                 AL
#
#     VisitingTeamGameNumber HomeTeam HomeTeamLeague  HomeTeamGameNumber  \
# 9                        1      BOS             AL                   1
# 30                       2      BOS             AL                   2
# 59                       3      DET             AL                   3
# 74                       4      DET             AL                   4
# 89                       5      DET             AL                   5
#
#     VisitorRunsScored       ...        HomeBatting7Name  HomeBatting7Position  \
# 9                   3       ...          Jackie Bradley                     8
# 30                  0       ...          Jackie Bradley                     8
# 59                  5       ...            James McCann                     2
# 74                  1       ...            James McCann                     2
# 89                  7       ...              Alex Avila                     2
#
#    HomeBatting8PlayerID  HomeBatting8Name  HomeBatting8Position  \
# 9              sandp001    Pablo Sandoval                     5
# 30             sandp001    Pablo Sandoval                     5
# 59             jonej006      JaCoby Jones                     8
# 74             jonej006      JaCoby Jones                     8
# 89             romia001     Andrew Romine                     8
#
#     HomeBatting9PlayerID HomeBatting9Name  HomeBatting9Position  \
# 9               leons001       Sandy Leon                     2
# 30              leons001       Sandy Leon                     2
# 59              iglej001    Jose Iglesias                     6
# 74              iglej001    Jose Iglesias                     6
# 89              iglej001    Jose Iglesias                     6
#
#     AdditionalInfo AcquisitionInfo
# 9              NaN               Y
# 30             NaN               Y
# 59             NaN               Y
# 74             NaN               Y
# 89             NaN               Y
#
# [5 rows x 161 columns]

# %% [markdown]
# team='NYY'

# %%
df_games['VisitingTeam'].value_counts().head()
# Out:
# MIA    81
# WAS    81
# ARI    81
# ANA    81
# TBA    81
# Name: VisitingTeam, dtype: int64

# %%
al_east = ['NYA','BOS','BAL','TBA','TOR']
al_central = ['CLE','MIN','DET','CHA','KCA']
al_west = ['ANA','OAK','TEX','HOU','SEA']
nl_east = ['NYN','PHI','WAS','MIA','ATL']
nl_central = ['STL','CHN','CIN','MIL','PIT']
nl_west = ['LAD','SFN','SDN','ARI','COL']

# %%
al = al_east + al_central + al_west
nl = nl_east + nl_central + nl_west

# %%
al
# Out:
# ['NYA',
#  'BOS',
#  'BAL',
#  'TBA',
#  'TOR',
#  'CLE',
#  'MIN',
#  'DET',
#  'CHA',
#  'KCA',
#  'ANA',
#  'OAK',
#  'TEX',
#  'HOU',
#  'SEA']

# %%
for team in al:

# %%
NYA = df_games[(df_games['HomeTeam'] ==  'NYA') | (df_games['VisitingTeam'] == 'NYA')]

# %%
team = 'BOS'

# %%
df_games[(df_games['VisitorLineScore'].str.len() > 9) & ((df_games['VisitingTeam'] == team)| (df_games['HomeTeam'] == team))][['VisitingTeam','VisitorLineScore','VisitorPitchers','VisitorPO','HomeTeam','HomeLineScore','HomePitchers','HomePO']]
# Out:
#      VisitingTeam     VisitorLineScore  VisitorPitchers  VisitorPO HomeTeam  \
# 30            PIT         000000000000                6         34      BOS
# 234           BOS           0000000013                2         30      TOR
# 460           BOS         30001201(10)                6         27      MIN
# 587           BOS        0000002200001                9         39      SLN
# 618           BOS           0002000000                4         27      OAK
# 944           PHI          40001000000                4         31      BOS
# 957           PHI         002001000000                4         34      BOS
# 1197          BOS          00002200003                5         33      TOR
# 1239          BOS          02000300002                6         33      TEX
# 1350          NYA     0000000010000003                8         48      BOS
# 1394          TOR      000030000010000                8         43      BOS
# 1493          BOS        0001030000001                6         38      SEA
# 1541          KCA           0004040000                7         29      BOS
# 1625          CHA          00020000000                4         32      BOS
# 1749          BOS           0000100011                5         30      NYA
# 2069          TOR  0100010000000000000                7         54      BOS
# 2209          BOS      100100003000017                9         45      TBA
# 2244          BOS          00016010002               10         33      BAL
# 2255          BOS          00000000001                6         33      BAL
#
#             HomeLineScore  HomePitchers  HomePO
# 30           000000000003             6      36
# 234            0000000010             6      30
# 460             000040020             7      27
# 587         1300000000000             5      39
# 618            0000110001             5      30
# 944           01210001001             5      33
# 957          111000000001             6      36
# 1197          30000100000             8      33
# 1239          10010011100             6      33
# 1350     0010000000000000             8      48
# 1394      000101100010001             5      45
# 1493        0300001000002             8      39
# 1541           0112201101             7      30
# 1625          00001100001             6      33
# 1749           0000100100             5      30
# 2069  0000000020000000001            12      57
# 2209      100201010000010            12      45
# 2244          13112000000             9      33
# 2255          00000000000             3      33

# %%
grp_teams = df_games.groupby('VisitingTeam')

# %%
df_games.shape
# Out:
# (2430, 162)

# %%
df_games['TotalRuns'] = df_games['VisitorRunsScored'] + df_games['HomeRunsScore']

# %%
df_games[df_games['TotalRuns'] == 32]
# Out:
#           Date  DoubleHeader DayOfWeek VisitingTeam VisitingTeamLeague  \
# 1510  20170726             0       Wed          MIA                 NL
#
#       VisitingTeamGameNumber HomeTeam HomeTeamLeague  HomeTeamGameNumber  \
# 1510                      99      TEX             AL                 101
#
#       VisitorRunsScored    ...     HomeBatting7Position  HomeBatting8PlayerID  \
# 1510                 22    ...                        2              gallj002
#
#      HomeBatting8Name  HomeBatting8Position  HomeBatting9PlayerID  \
# 1510       Joey Gallo                     7              robid003
#
#       HomeBatting9Name HomeBatting9Position  AdditionalInfo  AcquisitionInfo  \
# 1510     Drew Robinson                    8             NaN                Y
#
#      TotalRuns
# 1510        32
#
# [1 rows x 162 columns]

# %%
plt.plot(df_games['VisitingTeam'],)
